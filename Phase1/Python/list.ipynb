# %%
python_list = [1,2,3,4,5]
python_list
# Out:
# [1, 2, 3, 4, 5]

# %%
listt = ['welcome', 34, 0.34]
type(listt)
# Out:
# list

# %%
for i in listt:
    print(i, '=',type(i))
# Out:
# welcome = <class 'str'>
# 34 = <class 'int'>
# 0.34 = <class 'float'>

# %%
python_list.pop()
# Out:
# 5

# %%
python_list
# Out:
# [1, 2, 3, 4]

# %%
python_list.remove(2)

# %%
python_list
# Out:
# [1, 3, 4]
