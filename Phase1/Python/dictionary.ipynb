# %%
d = {
    "Name" : "vijayakumar",
    "City" : "Kallakurichi",
    "Age" : 21
}
print(d)
print(type(d))
# Out:
# {'Name': 'vijayakumar', 'City': 'Kallakurichi', 'Age': 21}
# <class 'dict'>

# %%
d['Name'],d['Age']
# Out:
# ('vijayakumar', 21)

# %%
for key in d.keys():
    print(key)
# Out:
# Name
# City
# Age

# %%
for value in d.values():
    print(value)
# Out:
# vijayakumar
# Kallakurichi
# 21

# %%
for key, value in d.items():
    print(f'{key} --> {value}')
# Out:
# Name --> vijayakumar
# City --> Kallakurichi
# Age --> 21

# %%
new_dict = dict(name='jarvis', age=23, city='Chennai')
print(new_dict)
# Out:
# {'name': 'jarvis', 'age': 23, 'city': 'Chennai'}

# %%
new_dict['email'] = 'abc@gmail.com'
print(new_dict)
# Out:
# {'name': 'jarvis', 'age': 23, 'city': 'Chennai', 'email': 'abc@gmail.com'}

# %%
del new_dict['age']
print(new_dict)
# Out:
# {'name': 'jarvis', 'city': 'Chennai', 'email': 'abc@gmail.com'}

# %%
new_dict.pop('email')
print(new_dict)
# Out:
# {'name': 'jarvis', 'city': 'Chennai'}

# %%
new_dict
# Out:
# {'name': 'jarvis', 'city': 'Chennai'}

# %%
new_dict.update(dict(name='vijay', age=21,city='kallakurichi'))
print(new_dict)
# Out:
# {'name': 'vijay', 'city': 'kallakurichi', 'age': 21}
